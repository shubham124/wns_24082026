# %% [markdown]
# # PreRequisites

# %% [markdown]
# ## Create Catalog and schema

# %%
# %sql
USE CATALOG wns24082026;
DROP TABLE IF EXISTS quickstart_schema.users;

# %% [markdown]
# ## Load daa from users001.csv

# %%
df = spark.read.csv(
    path="/Volumes/wns24082026/quickstart_schema/sandbox/datasets/user_dataset/users_001.csv",
    header=True,
    inferSchema=True,
)

df.write.saveAsTable("quickstart_schema.users", mode="OVERWRITE")

# %% [markdown]
# ## Read table

# %%
spark.read.table("quickstart_schema.users").limit(4).display()

# %% [markdown]
# # Schema Enforcement (default)

# %%
spark.read.csv(
    path="/Volumes/wns24082026/quickstart_schema/sandbox/datasets/user_dataset/users_006_new_column_education.csv",
    header=True,
    inferSchema=True,
).write.saveAsTable("quickstart_schema.users", mode="APPEND")

# %% [markdown]
# # Schema Evolution

# %%
spark.read.csv(
    path="/Volumes/wns24082026/quickstart_schema/sandbox/datasets/user_dataset/users_006_new_column_education.csv",
    header=True,
    inferSchema=True,
).write.option("mergeSchema", "true").saveAsTable("quickstart_schema.users", mode="APPEND")

# %%
spark.read.table("quickstart_schema.users").limit(4).display()

# %% [markdown]
# # Mismatch datatype
# ## Won't allow merge

# %%
spark.read.csv(
    path="/Volumes/wns24082026/quickstart_schema/sandbox/datasets/user_dataset/users_011_datatype_mismatch_dob.csv",
    header=True,
    inferSchema=True,
).write.saveAsTable("quickstart_schema.users", mode="APPEND")

# %%
spark.read.csv(
    path="/Volumes/wns24082026/quickstart_schema/sandbox/datasets/user_dataset/users_011_datatype_mismatch_dob.csv",
    header=True,
    inferSchema=True,
).write.option("mergeSchema", "true").saveAsTable("quickstart_schema.users", mode="APPEND")

# %% [markdown]
# # Less Column

# %%
spark.read.csv(
    path="/Volumes/wns24082026/quickstart_schema/sandbox/datasets/user_dataset/users_012_less_columns.csv",
    header=True,
    inferSchema=True,
).write.saveAsTable("quickstart_schema.users", mode="APPEND")

# %%
from pyspark.sql.functions import col

spark.read.table("quickstart_schema.users").filter(col("id").between( 5501,5504)).display()

# %% [markdown]
# # Schema with less columns and different column names

# %%
spark.read.csv(
    path="/Volumes/wns24082026/quickstart_schema/sandbox/datasets/user_dataset/users_013_less_columns_with_different_column_names.csv",
    header=True,
    inferSchema=True,
).write.saveAsTable("quickstart_schema.users", mode="APPEND")

# %%
spark.read.csv(
    path="/Volumes/wns24082026/quickstart_schema/sandbox/datasets/user_dataset/users_013_less_columns_with_different_column_names.csv",
    header=True,
    inferSchema=True,
).write.option("mergeSchema", True).saveAsTable("quickstart_schema.users", mode="APPEND")

# %%
from pyspark.sql.functions import col

spark.read.table("quickstart_schema.users").filter(col("user_id").between( 6001,6002)).display()

# %% [markdown]
# # Schema with less columns and different column names

# %%
spark.read.csv(
    path="/Volumes/wns24082026/quickstart_schema/sandbox/datasets/user_dataset/users_014_less_columns_with_different_column_names.csv",
    header=True,
    inferSchema=True,
).write.saveAsTable("quickstart_schema.users", mode="APPEND")

# %%
spark.read.table("quickstart_schema.users").filter(col("user_id").between( 6001,6004)).display()
