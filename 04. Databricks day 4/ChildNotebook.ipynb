# %%
print("Invoked Child Notebook 1")

# %%
dbutils.widgets.dropdown(
     name="technology",
    defaultValue="2G",
    choices=["2G","3G", "4G", "VOLTE"],
    label="Technology",
)

dbutils.widgets.text(name="cust_name", defaultValue="Shubham", label = "cutomer name")

# %%
print(dbutils.widgets.get("technology"))
print(dbutils.widgets.get("cust_name"))

# %%
print("Invoked Child Notebook 2")
dbutils.notebook.exit("Exited successfully")

# %%
print("Invoked Child Notebook 3")
