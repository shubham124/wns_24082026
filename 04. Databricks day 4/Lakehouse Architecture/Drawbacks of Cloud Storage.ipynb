# %% [markdown]
# # Prerequisites

# %% [markdown]
# ## Load Data users_001.csv

# %%
df = spark.read.csv(
    path="/Volumes/wns24082026/quickstart_schema/sandbox/datasets/user_dataset/users_001.csv",
    header=True,
    inferSchema=True,
)
display(df)

# %% [markdown]
# ## Write to Parquet

# %%
df.write.save(
    format="PARQUET",
    path="/Volumes/wns24082026/quickstart_schema/sandbox/output_parquet",
)

# %% [markdown]
# ## read Parquet

# %%
df_parquet = spark.read.parquet("/Volumes/wns24082026/quickstart_schema/sandbox/output_parquet")
df_parquet.display()

# %%
df_parquet.createOrReplaceTempView("users_vw")

# %%
# %sql
select * from users_vw

# %% [markdown]
# ## Disadvantage - Updates are not allowed

# %%
# %sql
update
  users_vw
SET
  country = 'Bharat'
where
  country = 'India'

# %% [markdown]
# ## Disadvantage - Overwrite no rollback or version history

# %%
from pyspark.sql.functions import col
df.filter(col("country")=="India").write.save(
    format="PARQUET",
    path="/Volumes/wns24082026/quickstart_schema/sandbox/output_parquet",
    mode = "OVERWRITE",
)
