# %%
dbutils.notebook.help()

# %%
dbutils.notebook.run(path= "/Workspace/Users/shubham35arora@gmail.com/wns_24082026/04. Databricks day 4/ChildNotebook", timeout_seconds=60)

# %%
rtv = dbutils.notebook.run(path= "/Workspace/Users/shubham35arora@gmail.com/wns_24082026/04. Databricks day 4/ChildNotebook", timeout_seconds=60, arguments={
    "technology" : "2G",
    "cust_name" : "Shubham Bro"
})
print(rtv)
