# %% [markdown]
# ## Dataframe

# %%
type(spark)
dfr = spark.read
type(dfr)

# %% [markdown]
# ## Create Dataframe

# %% [markdown]
# ### CSV

# %%
df = dfr.csv(
    path="/Volumes/wns24082026/quickstart_schema/sandbox/datasets/sample_dataset/users.csv",
    header =True,
    inferSchema=True
)
display(df)

# %% [markdown]
# ### Json

# %%
df = dfr.json(
    path="/Volumes/wns24082026/quickstart_schema/sandbox/datasets/sample_dataset/users_001.json",
)
display(df)

# %% [markdown]
# ### Parquet

# %%
df = spark.read.parquet("/Volumes/wns24082026/quickstart_schema/sandbox/datasets/sample_dataset/users.parquet")
display(df)

# %% [markdown]
# ## Attaching Custom Schema

# %%
from pyspark.sql.types import *
user_schema = StructType([
    StructField("id",IntegerType()),
    StructField("age",IntegerType()),
    StructField("gender",StringType()),
    StructField("designation",StringType()),
    StructField("salary",IntegerType())
])
df = spark.read.csv(
    path="/Volumes/wns24082026/quickstart_schema/sandbox/datasets/sample_dataset/users.csv",
    header =True,
    schema = user_schema)

display(df)

# %%
from pyspark.sql.types import *
user_schema = StructType([
    StructField("id",IntegerType()),
    StructField("age",IntegerType()),
    StructField("gender",IntegerType()),
    StructField("designation",StringType()),
    StructField("salary",IntegerType())
])
df = spark.read.csv(
    path="/Volumes/wns24082026/quickstart_schema/sandbox/datasets/sample_dataset/users.csv",
    header =True,
    schema = user_schema)

display(df)

# %% [markdown]
# ## Handling Bad Records

# %%
spark.read.json(
    path = "/Volumes/wns24082026/quickstart_schema/sandbox/datasets/access_logs.json",
    mode= "PERMISSIVE"
).display()

# %%
spark.read.option("columnNameOfCorruptRecord","Bad_Record").json(
    path = "/Volumes/wns24082026/quickstart_schema/sandbox/datasets/access_logs.json"
).display()

# %%
spark.read.json(
    path = "/Volumes/wns24082026/quickstart_schema/sandbox/datasets/access_logs.json",
    mode= "DROPMALFORMED"
).display()

# %%
spark.read.option("columnNameOfCorruptRecord", "bad_record").json(
    path="/Volumes/wns24082026/quickstart_schema/sandbox/datasets/access_logs.json",
    mode="FAILFAST",
).display()

# %% [markdown]
# ## Write MODE
# 1. ErrorIfExist
# 2. Override
# 3. Append
# 4. Ignore

# %%
df = spark.read.csv(
    path="/Volumes/wns24082026/quickstart_schema/sandbox/datasets/sample_dataset/users.csv",
    header=True,
    inferSchema=True,
)
df.write.save(
    mode="IGNORE",
    format="PARQUET",
    path="/Volumes/wns24082026/quickstart_schema/sandbox/output/output_parquet",
)

# %%
df = spark.read.csv(
    path="/Volumes/wns24082026/quickstart_schema/sandbox/datasets/sample_dataset/users.csv",
    header=True,
    inferSchema=True,
)
df.write.save(
    mode="ERRORIFEXIST",
    format="PARQUET",
    path="/Volumes/wns24082026/quickstart_schema/sandbox/output/output_parquet",
)

# %%
df = spark.read.csv(
    path="/Volumes/wns24082026/quickstart_schema/sandbox/datasets/sample_dataset/users.csv",
    header=True,
    inferSchema=True,
)
df.write.save(
    mode="IGNORE",
    format="PARQUET",
    path="/Volumes/wns24082026/quickstart_schema/sandbox/output/output_parquet",
)

# %%
df = spark.read.csv(
    path="/Volumes/wns24082026/quickstart_schema/sandbox/datasets/sample_dataset/users.csv",
    header=True,
    inferSchema=True,
)
df.write.save(
    mode="APPEND",
    format="PARQUET",
    path="/Volumes/wns24082026/quickstart_schema/sandbox/output/output_parquet",
)

# %%
spark.read.parquet("/Volumes/wns24082026/quickstart_schema/sandbox/output/output_parquet").count()
